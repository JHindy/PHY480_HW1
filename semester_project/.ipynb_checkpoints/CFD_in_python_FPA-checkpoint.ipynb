# %%
import numpy as np
import matplotlib.pyplot as plt
import time
# %matplotlib inline
from mpl_toolkits.mplot3d import Axes3D

# %%
# ===========================================================================
# Calculation of geometric properties of boundary element segments
# ===========================================================================
def geometry(x_list,y_list,seg_list):
    Ns = np.sum(seg_list) # total no. of segments
    Np = Ns+1 # total no. of segment end-points
    
    lb = np.sqrt((x_list[1:]-x_list[:-1])**2 + (y_list[1:]-y_list[:-1])**2)

    # total no. of segments at the beginning of each boundary element
    seg_num = np.zeros(seg_list.size)
    for i in range(1,seg_list.size):
        seg_num[i] = seg_num[i-1] + seg_list[i-1]

    x, y = [np.zeros(int(Np)) for i in range(2)]
    x[0] = x[-1] = x_list[0]; y[0] = y[-1] = y_list[0]
    for i in range(seg_list.size):
        x[int(seg_num[i]):int(seg_num[i]+seg_list[i]+1)] = np.linspace(x_list[i],x_list[i+1],int(seg_list[i]+1))
        y[int(seg_num[i]):int(seg_num[i]+seg_list[i]+1)] = np.linspace(y_list[i],y_list[i+1],int(seg_list[i]+1))

    # mid-pt of segments
    xm = 0.5*(x[1:] + x[:-1])
    ym = 0.5*(y[1:] + y[:-1])

    # list of mid-pts by boundary element index
    xms, yms = [[0]*seg_list.size for i in range(2)] # sequence with 1 element for each segment 
    for i in range(seg_list.size):
        xms[i] = np.array(xm[int(seg_num[i]):int(seg_num[i]+seg_list[i])])
        yms[i] = np.array(ym[int(seg_num[i]):int(seg_num[i]+seg_list[i])])

    # length of segments
    l = np.sqrt((x[1:]-x[:-1])**2 + (y[1:]-y[:-1])**2)

    # normal vectors
    ny = (x[:-1] - x[1:])/l
    nx = (y[1:] - y[:-1])/l        

    return x, y, xm, ym, xms, yms, nx, ny, l, Ns, seg_num, lb

# %%
# ===========================================================================
# Setting boundary conditions for each segement of boundary element
# ===========================================================================
def setBC(bct,bcv,seg_list,seg_num):
    BCT, BCV = [np.zeros(int(Ns)) for i in range(2)]
    for i in range(seg_list.size):
        BCT[int(seg_num[i]):int(seg_num[i]+seg_list[i])] = bct[i]
        BCV[int(seg_num[i]):int(seg_num[i]+seg_list[i])] = bcv[i]
        
    return BCT, BCV

# %%
# ===========================================================================
# Calculate integral coefficients F1 & F2 for a given array of points (x0,y0)
# ===========================================================================
def F1F2(x0,y0,x,y,l,nx,ny):    
    k = int(Ns) # no. of segments
    s = x0.size # no. of points

    A, B, E, F1, F2 = [np.zeros((k,s)) for i in range(5)]
    k = np.arange(k)
    s = np.arange(s)    
    K, S = np.meshgrid(k,s)
    
    A[K,:] = np.square(l[K]).T
    B[K,S] = 2*l[K]*(-(x[K]-x0[S])*ny[K] + (y[K]-y0[S])*nx[K])
    E[K,S] = (x[K]-x0[S])**2 + (y[K]-y0[S])**2

    M = 4*A*E - B**2
    D = 0.5*B/A
    
    zero = 1e-10 # a very small number to take care of floating point errors
    # Jth point (x0[J],y0[J]) intersects the (extended) Ith line segment
    I,J = np.where(M<zero)
    # jth point (x0[j],y0[j]) does not intersect (extended) ith line segment
    i,j = np.where(M>zero)

    # for M = 0 (lim D->0 D*ln(D)=0 )
    # since the log function cannot handle log(0), 'zeros' have been added to log(D) -> log(D+zero)
    F1[I,J] = 0.5*l[I]*(np.log(l[I]) \
                          + (1 + D[I,J])*np.log(np.abs(1 + D[I,J]) + zero) \
                          - D[I,J]*np.log(np.abs(D[I,J] + zero)) - 1)/np.pi
    # for M > 0
    H = np.arctan((2*A[i,j]+B[i,j])/np.sqrt(M[i,j])) - np.arctan(B[i,j]/np.sqrt(M[i,j]))
    F1[i,j] = 0.25*l[i]*(2*(np.log(l[i]) - 1) \
                           - D[i,j]*np.log(np.abs(E[i,j]/A[i,j])) \
                           + (1 + D[i,j])*np.log(np.abs(1 + 2*D[i,j] + E[i,j]/A[i,j])) \
                           + H*np.sqrt(M[i,j])/A[i,j])/np.pi
    F2[i,j] = l[i]*(nx[i]*(x[i] - x0[j]) + ny[i]*(y[i] - y0[j]))*H/np.sqrt(M[i,j])/np.pi

    return F1.T, F2.T

# %%
# ===========================================================================
# Build matrix system from F1 & F2 to find remaining BCs 
# ===========================================================================
def pqBC(F1,F2,BCT,BCV):
    Ns = BCT.size
    F2x = F2 - 0.5*np.eye(Ns)
    a,b = [np.zeros((Ns,Ns)) for i in range(2)]

    # phi is known - d(phi)/dn is unknown
    col_p = np.where(BCT==0)
    a[:,col_p] = -F1[:,col_p]
    b[:,col_p] = -F2x[:,col_p]
    # d(phi)/dn is known - phi is unknown
    col_q = np.where(BCT==1)
    a[:,col_q] = F2x[:,col_q]
    b[:,col_q] = F1[:,col_q]

    BCV2 = np.linalg.solve(a,np.dot(b,BCV))

    p = BCV2.copy()
    q = BCV2.copy()

    p[col_p] = BCV[col_p] # replace with known 'phi's
    q[col_q] = BCV[col_q] # replace with known 'd(phi)/dn's

    return p, q

# %%
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# GEOMETRY
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# (x,y)       segment end-points
# (xm, ym)    segment mid-points
# (xms,yms)   segment mid-point grouped by boundary elements
# (nx,ny)     normal vector components centered at (xm,ym)
# l           segment lengths
# Ns          total no. of segments
# seg_num     total no. of segments at the end of each boundary element
# lb          length of boundary element

# End-point coordinates of external rectangular domain (anti-clockwise / last pt = first pt)
x_list1 = np.array([-10.,50.,50.,-10.,-10.])
y_list1 = np.array([-20.,-20.,20,20,-20])
# No. of segments for each boundary element
seg_list1 = np.array([40,20,40,20])
# Indices
inlet = 3 # inlet
outlet = 1 # outlet

# Coordinates of airfoil (clockwise / last pt = first pt)
scale1 = 23
x_list2 = scale1*np.array([1.00000, 0.95041, 0.90067, 0.80097, 0.70102, 0.60085, 
                    0.50049, 0.40000, 0.29875, 0.24814, 0.19761, 0.14722, 
                    0.09710, 0.07217, 0.04742, 0.02297, 0.01098, 0.00000, 
                    0.01402, 0.02703, 0.05258, 0.07783, 0.10290, 0.15278, 
                    0.20239, 0.25186, 0.30125, 0.40000, 0.49951, 0.59915, 
                    0.69898, 0.79903, 0.89933, 0.94959, 1.00000, 1.00000])[::-1] # clockwise
y_list2 = -1*scale1*np.array([0.00105,  0.00990,  0.01816,  0.03296,  0.04551,  0.05580,
                       0.06356,  0.06837,  0.06875,  0.06668,  0.06276,  0.05665,  
                       0.04766,  0.04169,  0.03420,  0.02411,  0.01694,  0.00000, 
                       -0.01448, -0.01927, -0.02482, -0.02809, -0.03016, -0.03227, 
                       -0.03276, -0.03230, -0.03125, -0.02837, -0.02468, -0.02024, 
                       -0.01551, -0.01074, -0.00594, -0.00352, -0.00105, 0.00105])[::1] # clockwise

alpha1 = -30 # angle of attack
D2R = np.pi/180
rot1 = np.array([np.cos(alpha1*D2R), -np.sin(alpha1*D2R), np.sin(alpha1*D2R), np.cos(alpha1*D2R)]).reshape(2,2)

y_list2 = y_list2 - 10

x_list2 = np.dot(np.c_[x_list2,y_list2],rot1)[:,0]
y_list2 = np.dot(np.c_[x_list2,y_list2],rot1)[:,1]

Ns2 = x_list2.size - 1
seg_list2 = np.ones(Ns2)
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++

x1, y1, xm1, ym1, xms1, yms1, nx1, ny1, l1, Ns1, seg_num1, lb1 = geometry(x_list1,y_list1,seg_list1)
x2, y2, xm2, ym2, xms2, yms2, nx2, ny2, l2, Ns2, seg_num2, lb2 = geometry(x_list2,y_list2,seg_list2)

# Combining the internal & external boundaries
x = np.append(x1[:-1],x2[:-1])
y = np.append(y1[:-1],y2[:-1])
xm = np.append(xm1,xm2)
ym = np.append(ym1,ym2)
l = np.append(l1,l2)
nx = np.append(nx1,nx2)
ny = np.append(ny1,ny2)
Ns = Ns1 + Ns2
seg_list = np.append(seg_list1,seg_list2)
seg_num = np.zeros(seg_list.size)
for i in range(1,seg_list.size):
    seg_num[i] = seg_num[i-1] + seg_list[i-1]

fig = plt.figure(figsize=(12,12),dpi=100)
fig.add_subplot(111,aspect='equal')
plt.scatter(x,y,c=u'r',marker=u'o')
#plt.scatter(xm,ym,c=u'g',marker=u'^')
#plt.quiver(xm,ym,nx,ny)
plt.title('Boundary, Segments & Normal Vectors')
plt.show()

# %%
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# BOUNDARY CONDITIONS
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
U = 1. # volume flow rate
bct = np.ones(int(Ns)) # sequence of boundary condition types: 0->p, 1->q
bcv = np.zeros(int(Ns)) # sequence of boundary condition values
bcv[inlet]  = -U/lb1[inlet]
bcv[outlet] =  U/lb1[outlet]
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++

BCT, BCV = setBC(bct,bcv,seg_list,seg_num)

F1, F2 = F1F2(xm,ym,x,y,l,nx,ny) # obtaining F1 & F2 for segment mid-points
p, q = pqBC(F1,F2,BCT,BCV) # solving for additional boundary conditions

# %%
# Generating internal points (excludes boundary)
Nx = 20; Ny = 50;
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++

X = np.linspace(x.min(),x.max(),Nx)
Y = np.linspace(y.min(),y.max(),Ny)
X,Y = np.meshgrid(X[1:-1],Y[1:-1])

X = X.ravel(); Y = Y.ravel()

# Determines points within airfoil region by computing dot product [D] of
# normal vectors and vectors from mid-points on airfoil surface to points 
# of interest. If all the dot products are positive, point of interest 
# lies within the airfoil. Also, removes points on the outside which are a
# with a certain minimum distance [L] from the airfoil.
D = np.zeros((X.size,xm2.size))
L = np.zeros((X.size,xm2.size))
I = []
for i in range(X.size):
    for j in range(xm2.size):
        D[i,j] = (X[i]-xm2[j])*nx2[j] + (Y[i]-ym2[j])*ny2[j]
        L[i,j] = np.sqrt((X[i] - xm2[j])**2 + (Y[i] - ym2[j])**2)
    if ((D[i,:]>0).all()):
        I.append(i)
    elif ((L[i,:]<1).any()):
        I.append(i)
        
X = np.delete(X.ravel(),I)
Y = np.delete(Y.ravel(),I)

fig = plt.figure(figsize=(12,12),dpi=100)
fig.add_subplot(111,aspect='equal')
plt.fill(x1,y1,fill=False,lw=3)
plt.fill(x2,y2,fill=True,lw=3)
plt.scatter(X,Y,c=u'b',marker=u'*')
plt.title(r'Internal Points for Calculation of $\phi$, $u$ & $v$')
plt.show()

# %%
# Calculate velocity (u,v) at internal grid points (X,Y)
# ===========================================================================
delta_x = delta_y = 0.05
F1, F2 = F1F2(X+delta_x,Y,x,y,l,nx,ny)
phi_x_plus = (np.dot(F2,p) - np.dot(F1,q))
F1, F2 = F1F2(X-delta_x,Y,x,y,l,nx,ny)
phi_x_minus = (np.dot(F2,p) - np.dot(F1,q))
F1, F2 = F1F2(X,Y+delta_y,x,y,l,nx,ny)
phi_y_plus = (np.dot(F2,p) - np.dot(F1,q))
F1, F2 = F1F2(X,Y-delta_y,x,y,l,nx,ny)
phi_y_minus = (np.dot(F2,p) - np.dot(F1,q))

# Central difference to determine velocity
u = 0.5*(phi_x_plus - phi_x_minus)/delta_x
v = 0.5*(phi_y_plus - phi_y_minus)/delta_y

fig = plt.figure(figsize=(12,12), dpi=100)
fig.add_subplot(111,aspect='equal')
plt.fill(x1,y1,fill=False,lw=3)
plt.fill(x2,y2,fill=True,lw=3)
plt.quiver(X,Y,u,v)
plt.title('Potential flow past an airfoil')
plt.show()

# %%
num_points_1 = []
run_time_1 = []
for Nx in range(20, 46, 1):
    start_time = time.time()
    # Generating internal points (excludes boundary)
    Ny = Nx;
    # +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++

    X = np.linspace(x.min(),x.max(),Nx)
    Y = np.linspace(y.min(),y.max(),Ny)
    X,Y = np.meshgrid(X[1:-1],Y[1:-1])

    X = X.ravel(); Y = Y.ravel()

    # Determines points within airfoil region by computing dot product [D] of
    # normal vectors and vectors from mid-points on airfoil surface to points 
    # of interest. If all the dot products are positive, point of interest 
    # lies within the airfoil. Also, removes points on the outside which are a
    # with a certain minimum distance [L] from the airfoil.
    D = np.zeros((X.size,xm2.size))
    L = np.zeros((X.size,xm2.size))
    I = []
    for i in range(X.size):
        for j in range(xm2.size):
            D[i,j] = (X[i]-xm2[j])*nx2[j] + (Y[i]-ym2[j])*ny2[j]
            L[i,j] = np.sqrt((X[i] - xm2[j])**2 + (Y[i] - ym2[j])**2)
        if ((D[i,:]>0).all()):
            I.append(i)
        elif ((L[i,:]<1).any()):
            I.append(i)

    X = np.delete(X.ravel(),I)
    Y = np.delete(Y.ravel(),I)

    # Calculate velocity (u,v) at internal grid points (X,Y)
    # ===========================================================================
    delta_x = delta_y = 0.05
    F1, F2 = F1F2(X+delta_x,Y,x,y,l,nx,ny)
    phi_x_plus = (np.dot(F2,p) - np.dot(F1,q))
    F1, F2 = F1F2(X-delta_x,Y,x,y,l,nx,ny)
    phi_x_minus = (np.dot(F2,p) - np.dot(F1,q))
    F1, F2 = F1F2(X,Y+delta_y,x,y,l,nx,ny)
    phi_y_plus = (np.dot(F2,p) - np.dot(F1,q))
    F1, F2 = F1F2(X,Y-delta_y,x,y,l,nx,ny)
    phi_y_minus = (np.dot(F2,p) - np.dot(F1,q))

    # Central difference to determine velocity
    u = 0.5*(phi_x_plus - phi_x_minus)/delta_x
    v = 0.5*(phi_y_plus - phi_y_minus)/delta_y
    end_time = (time.time() - start_time)
    print("%s Points took:" % Nx)
    print("%s seconds" % end_time)
    num_points_1.append(Nx)
    run_time_1.append(end_time)
# Out:
# 20 Points took:
# 0.5069482326507568 seconds
# 21 Points took:
# 0.4969327449798584 seconds
# 22 Points took:
# 0.6366336345672607 seconds
# 23 Points took:
# 0.7290477752685547 seconds
# 24 Points took:
# 0.9207324981689453 seconds
# 25 Points took:
# 0.9559750556945801 seconds
# 26 Points took:
# 1.1194064617156982 seconds
# 27 Points took:
# 1.2972722053527832 seconds
# 28 Points took:
# 1.5565989017486572 seconds
# 29 Points took:
# 1.6432626247406006 seconds
# 30 Points took:
# 1.943673849105835 seconds
# 31 Points took:
# 2.027245283126831 seconds
# 32 Points took:
# 2.3376147747039795 seconds
# 33 Points took:
# 2.5884861946105957 seconds
# 34 Points took:
# 2.885922431945801 seconds
# 35 Points took:
# 3.262761354446411 seconds
# 36 Points took:
# 3.663930654525757 seconds
# 37 Points took:
# 4.925794363021851 seconds
# 38 Points took:
# 5.104312896728516 seconds
# 39 Points took:
# 6.011361598968506 seconds
# 40 Points took:
# 7.472599029541016 seconds
# 41 Points took:
# 7.891503095626831 seconds
# 42 Points took:
# 9.687888622283936 seconds
# 43 Points took:
# 11.515177011489868 seconds
# 44 Points took:
# 13.114621877670288 seconds
# 45 Points took:
# 15.661589860916138 seconds

# %%
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# GEOMETRY
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# (x,y)       segment end-points
# (xm, ym)    segment mid-points
# (xms,yms)   segment mid-point grouped by boundary elements
# (nx,ny)     normal vector components centered at (xm,ym)
# l           segment lengths
# Ns          total no. of segments
# seg_num     total no. of segments at the end of each boundary element
# lb          length of boundary element

# End-point coordinates of external rectangular domain (anti-clockwise / last pt = first pt)
x_list1 = np.array([-10.,50.,50.,-10.,-10.])
y_list1 = np.array([-20.,-20.,20,20,-20])
# No. of segments for each boundary element
seg_list1 = np.array([40,20,40,20])
# Indices
inlet = 3 # inlet
outlet = 1 # outlet

# Coordinates of airfoil (clockwise / last pt = first pt)
scale1 = 23
x_list2 = scale1*np.array([1.00000, 0.95041, 0.90067, 0.80097, 0.70102, 0.60085, 
                    0.50049, 0.40000, 0.29875, 0.24814, 0.19761, 0.14722, 
                    0.09710, 0.07217, 0.04742, 0.02297, 0.01098, 0.00000, 
                    0.01402, 0.02703, 0.05258, 0.07783, 0.10290, 0.15278, 
                    0.20239, 0.25186, 0.30125, 0.40000, 0.49951, 0.59915, 
                    0.69898, 0.79903, 0.89933, 0.94959, 1.00000, 1.00000])[::-1] # clockwise
y_list2 = -1*scale1*np.array([0.00105,  0.00990,  0.01816,  0.03296,  0.04551,  0.05580,
                       0.06356,  0.06837,  0.06875,  0.06668,  0.06276,  0.05665,  
                       0.04766,  0.04169,  0.03420,  0.02411,  0.01694,  0.00000, 
                       -0.01448, -0.01927, -0.02482, -0.02809, -0.03016, -0.03227, 
                       -0.03276, -0.03230, -0.03125, -0.02837, -0.02468, -0.02024, 
                       -0.01551, -0.01074, -0.00594, -0.00352, -0.00105, 0.00105])[::1] # clockwise

scale2 = 30
x_list3 = scale2*np.array([1.00000, 0.95041, 0.90067, 0.80097, 0.70102, 0.60085, 
                    0.50049, 0.40000, 0.29875, 0.24814, 0.19761, 0.14722, 
                    0.09710, 0.07217, 0.04742, 0.02297, 0.01098, 0.00000, 
                    0.01402, 0.02703, 0.05258, 0.07783, 0.10290, 0.15278, 
                    0.20239, 0.25186, 0.30125, 0.40000, 0.49951, 0.59915, 
                    0.69898, 0.79903, 0.89933, 0.94959, 1.00000, 1.00000])[::-1] # clockwise
y_list3 = -1*scale2*np.array([0.00105,  0.00990,  0.01816,  0.03296,  0.04551,  0.05580,
                       0.06356,  0.06837,  0.06875,  0.06668,  0.06276,  0.05665,  
                       0.04766,  0.04169,  0.03420,  0.02411,  0.01694,  0.00000, 
                       -0.01448, -0.01927, -0.02482, -0.02809, -0.03016, -0.03227, 
                       -0.03276, -0.03230, -0.03125, -0.02837, -0.02468, -0.02024, 
                       -0.01551, -0.01074, -0.00594, -0.00352, -0.00105, 0.00105])[::1] # clockwise

alpha1 = -10 # angle of attack
alpha2 = -55
D2R = np.pi/180
rot1 = np.array([np.cos(alpha1*D2R), -np.sin(alpha1*D2R), np.sin(alpha1*D2R), np.cos(alpha1*D2R)]).reshape(2,2)
rot2 = np.array([np.cos(alpha2*D2R), -np.sin(alpha2*D2R), np.sin(alpha2*D2R), np.cos(alpha2*D2R)]).reshape(2,2)

y_list2 = y_list2 - 10

x_list3 = x_list3 - 20
y_list3 = y_list3 - 40

x_list2 = np.dot(np.c_[x_list2,y_list2],rot1)[:,0]
y_list2 = np.dot(np.c_[x_list2,y_list2],rot1)[:,1]
x_list3 = np.dot(np.c_[x_list3,y_list3],rot2)[:,0]
y_list3 = np.dot(np.c_[x_list3,y_list3],rot2)[:,1]
Ns2 = x_list2.size - 1
Ns3 = x_list3.size - 1
seg_list2 = np.ones(Ns2)
seg_list3 = np.ones(Ns3)
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++

x1, y1, xm1, ym1, xms1, yms1, nx1, ny1, l1, Ns1, seg_num1, lb1 = geometry(x_list1,y_list1,seg_list1)
x2, y2, xm2, ym2, xms2, yms2, nx2, ny2, l2, Ns2, seg_num2, lb2 = geometry(x_list2,y_list2,seg_list2)
x3, y3, xm3, ym3, xms3, yms3, nx3, ny3, l3, Ns3, seg_num3, lb3 = geometry(x_list3,y_list3,seg_list3)

# Combining the internal & external boundaries
x = np.append(x1[:-1],x2[:-1])
x = np.append(x,x3[:-1])
y = np.append(y1[:-1],y2[:-1])
y = np.append(y,y3[:-1])
xm = np.append(xm1,xm2)
xm = np.append(xm,xm3)
ym = np.append(ym1,ym2)
ym = np.append(ym, ym3)
l = np.append(l1,l2)
l = np.append(l,l3)
nx = np.append(nx1,nx2)
nx = np.append(nx,nx3)
ny = np.append(ny1,ny2)
ny = np.append(ny,ny3)
Ns = Ns1 + Ns2 + Ns3
seg_list = np.append(seg_list1,seg_list2)
seg_list = np.append(seg_list, seg_list3)
seg_num = np.zeros(seg_list.size)
for i in range(1,seg_list.size):
    seg_num[i] = seg_num[i-1] + seg_list[i-1]

fig = plt.figure(figsize=(12,12),dpi=100)
fig.add_subplot(111,aspect='equal')
plt.scatter(x,y,c=u'r',marker=u'o')
#plt.scatter(xm,ym,c=u'g',marker=u'^')
#plt.quiver(xm,ym,nx,ny)
plt.title('Boundary, Segments & Normal Vectors')
plt.show()

# %%
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# BOUNDARY CONDITIONS
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
U = 1. # volume flow rate
bct = np.ones(int(Ns)) # sequence of boundary condition types: 0->p, 1->q
bcv = np.zeros(int(Ns)) # sequence of boundary condition values
bcv[inlet]  = -U/lb1[inlet]
bcv[outlet] =  U/lb1[outlet]
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++

BCT, BCV = setBC(bct,bcv,seg_list,seg_num)

F1, F2 = F1F2(xm,ym,x,y,l,nx,ny) # obtaining F1 & F2 for segment mid-points
p, q = pqBC(F1,F2,BCT,BCV) # solving for additional boundary conditions

# %%
# Generating internal points (excludes boundary)
Nx = 20; Ny = 50;
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++

X = np.linspace(x.min(),x.max(),Nx)
Y = np.linspace(y.min(),y.max(),Ny)
X,Y = np.meshgrid(X[1:-1],Y[1:-1])

X = X.ravel(); Y = Y.ravel()

# Determines points within airfoil region by computing dot product [D] of
# normal vectors and vectors from mid-points on airfoil surface to points 
# of interest. If all the dot products are positive, point of interest 
# lies within the airfoil. Also, removes points on the outside which are a
# with a certain minimum distance [L] from the airfoil.
D = np.zeros((X.size,xm2.size))
L = np.zeros((X.size,xm2.size))
I = []
for i in range(X.size):
    for j in range(xm2.size):
        D[i,j] = (X[i]-xm2[j])*nx2[j] + (Y[i]-ym2[j])*ny2[j]
        L[i,j] = np.sqrt((X[i] - xm2[j])**2 + (Y[i] - ym2[j])**2)
    if ((D[i,:]>0).all()):
        I.append(i)
    elif ((L[i,:]<1).any()):
        I.append(i)
        
D2 = np.zeros((X.size,xm3.size))
L2 = np.zeros((X.size,xm3.size))
for i in range(X.size):
    for j in range(xm2.size):
        D2[i,j] = (X[i]-xm3[j])*nx3[j] + (Y[i]-ym3[j])*ny3[j]
        L2[i,j] = np.sqrt((X[i] - xm3[j])**2 + (Y[i] - ym3[j])**2)
    if ((D2[i,:]>0).all()):
        I.append(i)
    elif ((L2[i,:]<1).any()):
        I.append(i)
        
X = np.delete(X.ravel(),I)
Y = np.delete(Y.ravel(),I)

fig = plt.figure(figsize=(12,12),dpi=100)
fig.add_subplot(111,aspect='equal')
plt.fill(x1,y1,fill=False,lw=3)
plt.fill(x2,y2,fill=True,lw=3)
plt.fill(x3,y3,fill=True,lw=3)
plt.scatter(X,Y,c=u'b',marker=u'*')
plt.title(r'Internal Points for Calculation of $\phi$, $u$ & $v$')
plt.show()

# %%
# Calculate velocity (u,v) at internal grid points (X,Y)
# ===========================================================================
delta_x = delta_y = 0.05
F1, F2 = F1F2(X+delta_x,Y,x,y,l,nx,ny)
phi_x_plus = (np.dot(F2,p) - np.dot(F1,q))
F1, F2 = F1F2(X-delta_x,Y,x,y,l,nx,ny)
phi_x_minus = (np.dot(F2,p) - np.dot(F1,q))
F1, F2 = F1F2(X,Y+delta_y,x,y,l,nx,ny)
phi_y_plus = (np.dot(F2,p) - np.dot(F1,q))
F1, F2 = F1F2(X,Y-delta_y,x,y,l,nx,ny)
phi_y_minus = (np.dot(F2,p) - np.dot(F1,q))

# Central difference to determine velocity
u = 0.5*(phi_x_plus - phi_x_minus)/delta_x
v = 0.5*(phi_y_plus - phi_y_minus)/delta_y

fig = plt.figure(figsize=(12,12), dpi=100)
fig.add_subplot(111,aspect='equal')
plt.fill(x1,y1,fill=False,lw=3)
plt.fill(x2,y2,fill=True,lw=3)
plt.fill(x3,y3,fill=True,lw=3)
plt.quiver(X,Y,u,v)
plt.title('Potential flow past an airfoil')
plt.show()

# %%
num_points_2 = []
run_time_2 = []
for Nx in range(20, 46, 1):
    start_time = time.time()
    # Generating internal points (excludes boundary)
    Ny = Nx;
    # +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++

    X = np.linspace(x.min(),x.max(),Nx)
    Y = np.linspace(y.min(),y.max(),Ny)
    X,Y = np.meshgrid(X[1:-1],Y[1:-1])

    X = X.ravel(); Y = Y.ravel()

    # Determines points within airfoil region by computing dot product [D] of
    # normal vectors and vectors from mid-points on airfoil surface to points 
    # of interest. If all the dot products are positive, point of interest 
    # lies within the airfoil. Also, removes points on the outside which are a
    # with a certain minimum distance [L] from the airfoil.
    D = np.zeros((X.size,xm2.size))
    L = np.zeros((X.size,xm2.size))
    I = []
    for i in range(X.size):
        for j in range(xm2.size):
            D[i,j] = (X[i]-xm2[j])*nx2[j] + (Y[i]-ym2[j])*ny2[j]
            L[i,j] = np.sqrt((X[i] - xm2[j])**2 + (Y[i] - ym2[j])**2)
        if ((D[i,:]>0).all()):
            I.append(i)
        elif ((L[i,:]<1).any()):
            I.append(i)

    D2 = np.zeros((X.size,xm3.size))
    L2 = np.zeros((X.size,xm3.size))
    for i in range(X.size):
        for j in range(xm2.size):
            D2[i,j] = (X[i]-xm3[j])*nx3[j] + (Y[i]-ym3[j])*ny3[j]
            L2[i,j] = np.sqrt((X[i] - xm3[j])**2 + (Y[i] - ym3[j])**2)
        if ((D2[i,:]>0).all()):
            I.append(i)
        elif ((L2[i,:]<1).any()):
            I.append(i)

    X = np.delete(X.ravel(),I)
    Y = np.delete(Y.ravel(),I)

    # Calculate velocity (u,v) at internal grid points (X,Y)
    # ===========================================================================
    delta_x = delta_y = 0.05
    F1, F2 = F1F2(X+delta_x,Y,x,y,l,nx,ny)
    phi_x_plus = (np.dot(F2,p) - np.dot(F1,q))
    F1, F2 = F1F2(X-delta_x,Y,x,y,l,nx,ny)
    phi_x_minus = (np.dot(F2,p) - np.dot(F1,q))
    F1, F2 = F1F2(X,Y+delta_y,x,y,l,nx,ny)
    phi_y_plus = (np.dot(F2,p) - np.dot(F1,q))
    F1, F2 = F1F2(X,Y-delta_y,x,y,l,nx,ny)
    phi_y_minus = (np.dot(F2,p) - np.dot(F1,q))

    # Central difference to determine velocity
    u = 0.5*(phi_x_plus - phi_x_minus)/delta_x
    v = 0.5*(phi_y_plus - phi_y_minus)/delta_y
    end_time = (time.time() - start_time)
    print("%s Points took:" % Nx)
    print("%s seconds" % end_time)
    num_points_2.append(Nx)
    run_time_2.append(end_time)
# Out:
# 20 Points took:
# 0.709632158279419 seconds
# 21 Points took:
# 0.7694976329803467 seconds
# 22 Points took:
# 0.8793513774871826 seconds
# 23 Points took:
# 0.9860305786132812 seconds
# 24 Points took:
# 1.101020336151123 seconds
# 25 Points took:
# 1.251185417175293 seconds
# 26 Points took:
# 1.4931046962738037 seconds
# 27 Points took:
# 1.7698283195495605 seconds
# 28 Points took:
# 2.0108482837677 seconds
# 29 Points took:
# 2.4907660484313965 seconds
# 30 Points took:
# 2.6038589477539062 seconds
# 31 Points took:
# 2.733961582183838 seconds
# 32 Points took:
# 3.09885573387146 seconds
# 33 Points took:
# 3.4100754261016846 seconds
# 34 Points took:
# 4.19603705406189 seconds
# 35 Points took:
# 4.480296850204468 seconds
# 36 Points took:
# 5.369440078735352 seconds
# 37 Points took:
# 6.569170236587524 seconds
# 38 Points took:
# 7.083813190460205 seconds
# 39 Points took:
# 9.258825540542603 seconds
# 40 Points took:
# 9.433971166610718 seconds
# 41 Points took:
# 13.952277421951294 seconds
# 42 Points took:
# 18.087416887283325 seconds
# 43 Points took:
# 20.606221437454224 seconds
# 44 Points took:
# 24.32771897315979 seconds
# 45 Points took:
# 29.453650951385498 seconds

# %%
fig, ax = plt.subplots(2,1, figsize = [15,14])
ax[0].plot(num_points_1, run_time_1, label = "Single Airfoil")
ax[0].plot(num_points_2, run_time_2, label = "Double Airfoil")
ax[0].set_xlabel('Number of points (x and y)')
ax[0].set_ylabel('Runtime (s)')
ax[0].set_title('Runtime of two airflow simulations')
ax[0].legend()

x = range(20, 46, 1)
log_time_1 = np.log(np.array(run_time_1))
log_time_2 = np.log(np.array(run_time_2))
coef1 = np.polyfit(num_points_1, log_time_1, 1)
coef2 = np.polyfit(num_points_2, log_time_2, 1)

poly1d_1 = np.poly1d(coef1)
poly1d_2 = np.poly1d(coef2) 

ax[1].scatter(num_points_1, log_time_1, label = "Single Airfoil")
ax[1].scatter(num_points_2, log_time_2, label = "Double Airfoil")
ax[1].plot(x, poly1d_1(x))
ax[1].plot(x, poly1d_2(x))
ax[1].set_xlabel('Number of points (x and y)')
ax[1].set_ylabel('Runtime (log(s))')
ax[1].set_title('Runtime of two airflow simulations')
ax[1].legend()

# %%
print('Fit for single airfoil:')
print(str(round(coef1[0], 3)) + '*x' + str(round(coef1[1], 3)))
print('Which gives a fit equation of:')
print(str(round(np.exp(coef1[1]), 4)) + '*e^(' + str(round(coef1[0], 3)) + '*x' +')')
print('Fit for double airfoil:')
print(str(round(coef2[0], 3)) + '*x' + str(round(coef2[1], 3)))
print('Which gives a fit equation of:')
print(str(round(np.exp(coef2[1]), 4)) + '*e^(' + str(round(coef2[0], 3)) + '*x' +')')
# Out:
# Fit for single airfoil:
# 0.135*x-3.432
# Which gives a fit equation of:
# 0.0323*e^(0.135*x)
# Fit for double airfoil:
# 0.146*x-3.413
# Which gives a fit equation of:
# 0.033*e^(0.146*x)
